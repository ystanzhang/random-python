# %%
d = ["mobile","samsung","sam","sung","man","mango","icecream","and","go","i","like","ice","cream"]
s = 'icecream'

# %%
def wordBreak(d, s):
    size = len(s)
    for i in range(len(s)):
        if s[:1] in d and wordBreak(d, s[i:]):
            return True
    return False

# %%
if wordBreak(d, s):
    print 'yes'
else:
    print 'no'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-d94382384029> in <module>()
# ----> 1 if wordBreak(d, s):
#       2     print 'yes'
#       3 else:
#       4     print 'no'
#
# <ipython-input-32-04ea0820f084> in wordBreak(d, s)
#       2     size = len(s)
#       3     for i in range(len(s)):
# ----> 4         if s[:1] in d and wordBreak(d, s[i:]):
#       5             return True
#       6     return False
#
# <ipython-input-32-04ea0820f084> in wordBreak(d, s)
#       2     size = len(s)
#       3     for i in range(len(s)):
# ----> 4         if s[:1] in d and wordBreak(d, s[i:]):
#       5             return True
#       6     return False
#
# <ipython-input-32-04ea0820f084> in wordBreak(d, s)
#       2     size = len(s)
#       3     for i in range(len(s)):
# ----> 4         if s[:1] in d and wordBreak(d, s[i:]):
#       5             return True
# ...

# %%
i = 3
print (s[:i], s[i:])
# Out:
# ('ice', 'cream')
